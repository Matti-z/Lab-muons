# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from pathlib import Path
import numpy as np
from iminuit import Minuit
from iminuit.cost import LeastSquares
from scipy.stats import chi2

# %%
def line( x , a , b):
    return a*x +b

# %% [markdown]
# # Plateaux

# %%
#prendo path per tutti uguale
DATA_FILE = Path('Data/calibration') / 'ch_4-5.csv'
if not DATA_FILE.exists():
    for p in Path.cwd().parents:
        candidate = p / 'Data' / 'ch_4-5.csv'
        if candidate.exists():
            DATA_FILE = candidate
            break
df_varia = pd.read_csv(DATA_FILE, sep = r',', skiprows = 0, engine='python')
display(df_varia)
# Out:
#     p_tensione[V]  g_tensione[V]  p_threshold[mV]  g_threshold[mV]  p_count  \
# 0             780            950              141              120   1420.0
# 1             780            950              253              153    128.0
# 2             780            950              200              183    418.0
# 3             780            950              151              209   1117.0
# 4             780            950              234              192    218.0
# 5             780            950              212              201    378.0
# 6             780            950              238              224    192.0
# 7             780            950              187              171    563.0
# 8             800            950              237              167    373.0
# 9             800            980              187              173   1088.0
# 10            800            980              212              190    635.0
# 11            800            980              230              205    415.0
# 12            800            980              249              248    304.0
# 13            800            980              253              254    264.0
# 14            800            950              175              206   1298.0
# 15            780            950              230              180    231.0
# 16            780            950              173              254    727.0
# 17            780            950              222              242    240.0
# 18            780            950              211              176    302.0
# 19            780            950              125              217   2058.0
# 20            780            950              116              217   2532.0
# 21            780            950              106              217   3314.0
# 22            780            950               96              217   4252.0
# 23            780            950               85              217   4889.0
# 24            780            950               76              217   5300.0
# 25            780            950               66              217   5642.0
# 26            780            950               54              217   6422.0
# 27            780            950               48              217   6932.0
# 28            780            950               60              217   6004.0
# 29            980            950              150              215  16592.0
# 30            880            950              224              215   4087.0
# 31            880            950              205              215   4720.0
# 32            880           1050              194              215   5059.0
# 33            880           1050              175              187   5263.0
# 34            880           1050              166              174   5557.0
# 35            880           1050              158              163   5559.0
# 36            880           1050              148              148   5784.0
# 37            880           1050              138              136   5893.0
# 38            880           1050              121              123   6389.0
# 39            880           1050              108              114   7130.0
# 40            880           1050               98              104   7936.0
# 41            880           1050               89               94   9751.0
# 42            880           1050               79               81  13408.0
# 43            880           1050              239               68   1411.0
# 44            880           1050              253               49   1635.0
# 45            880           1050              253              205   1213.0
# 46            880           1050              223              247   2270.0
# 47            880           1050               42              254  57268.0
# 48            880           1050              178              166      NaN
# 49            880           1050              178              166      NaN
# 50            880           1050              178              166      NaN
# 51            880           1050              178              166      NaN
# 52            880           1050              178              166      NaN
#
#     g_count  pg_doppie  gm_doppie  pgm_triple  m_tensione[V]  m_threshold[mV]
# 0    1548.0      683.0        NaN         NaN            NaN              NaN
# 1     815.0       51.0        NaN         NaN            NaN              NaN
# 2     466.0      131.0        NaN         NaN            NaN              NaN
# 3     269.0      133.0        NaN         NaN            NaN              NaN
# 4     372.0       65.0        NaN         NaN            NaN              NaN
# 5     334.0      106.0        NaN         NaN            NaN              NaN
# 6     197.0       37.0        NaN         NaN            NaN              NaN
# 7     518.0      176.0        NaN         NaN            NaN              NaN
# 8     557.0      126.0        NaN         NaN            NaN              NaN
# 9    1115.0      466.0        NaN         NaN            NaN              NaN
# 10    820.0      236.0        NaN         NaN            NaN              NaN
# 11    586.0      144.0        NaN         NaN            NaN              NaN
# 12    300.0       80.0        NaN         NaN            NaN              NaN
# 13    293.0       81.0        NaN         NaN            NaN              NaN
# 14    270.0      160.0        NaN         NaN            NaN              NaN
# 15    480.0       79.0        NaN         NaN            NaN              NaN
# 16    108.0       52.0        NaN         NaN            NaN              NaN
# 17    151.0       30.0        NaN         NaN            NaN              NaN
# 18    526.0      122.0       75.0        64.0            NaN              NaN
# 19      NaN      136.0       72.0        63.0            NaN              NaN
# 20      NaN      129.0       86.0        74.0            NaN              NaN
# 21      NaN      130.0       68.0        62.0            NaN              NaN
# 22      NaN      143.0       68.0        66.0            NaN              NaN
# 23      NaN      160.0       82.0        80.0            NaN              NaN
# 24      NaN      174.0       88.0        85.0            NaN              NaN
# 25      NaN      137.0       74.0        73.0            NaN              NaN
# 26      NaN      163.0       92.0        93.0            NaN              NaN
# 27      NaN      182.0       83.0        82.0            NaN              NaN
# 28      NaN      410.0      199.0       195.0            NaN              NaN
# 29      NaN      188.0       82.0        81.0            NaN              NaN
# 30      NaN      155.0       73.0        73.0            NaN              NaN
# 31      NaN      162.0       80.0        75.0            NaN              NaN
# 32   2496.0        NaN     1023.0      1012.0         1150.0            254.0
# 33   3488.0        NaN     1388.0      1376.0         1150.0            254.0
# 34   4207.0        NaN     1658.0      1649.0         1150.0            254.0
# 35   4528.0        NaN     1667.0      1652.0         1150.0            254.0
# 36   4847.0        NaN     2671.0      2662.0         1150.0            189.0
# 37   5155.0        NaN     2676.0      2660.0         1150.0            191.0
# 38   5543.0        NaN     3420.0      3395.0         1150.0             76.0
# 39   5593.0        NaN     3450.0      3428.0         1150.0             50.0
# 40   6001.0        NaN     3558.0      3562.0         1150.0             40.0
# 41   6359.0        NaN     3636.0      3598.0         1150.0             40.0
# 42   7102.0        NaN     3590.0      2493.0         1150.0             35.0
# 43   9762.0        NaN     3752.0       623.0         1150.0             26.0
# 44  19373.0        NaN     3835.0      1086.0         1150.0             26.0
# 45   3033.0        NaN     1972.0      1357.0         1150.0             26.0
# 46   1714.0        NaN     1047.0      1003.0         1150.0             26.0
# 47   1570.0        NaN      968.0       957.0         1150.0             26.0
# 48      NaN     4303.0     3024.0      2978.0         1200.0             40.0
# 49      NaN        NaN        NaN         NaN         1200.0             40.0
# 50      NaN        NaN        NaN         NaN         1200.0             40.0
# 51      NaN        NaN        NaN         NaN         1200.0             40.0
# 52      NaN        NaN        NaN         NaN         1200.0             40.0

# %%
df_880p = df_varia[df_varia['p_tensione[V]'] == 880]
df_1050g = df_varia[df_varia['g_tensione[V]'] == 1050]
fig = go.Figure()

fig.add_trace(go.Scatter(x=df_880p['p_threshold[mV]'], y=df_880p['p_count'], mode='markers', name='p_threshold[mV] = 880', error_y=dict(type='data', array=np.sqrt(df_880p['p_count']), visible=True)))
fig.add_trace(go.Scatter(x=df_1050g['g_threshold[mV]'], y=df_1050g['g_count'], mode='markers', name='g_threshold[mV] = 1050', error_y=dict(type='data', array=np.sqrt(df_1050g['g_count']), visible=True)))

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=df_880p['p_threshold[mV]'], y=df_880p['p_count']/7200, mode='markers', name='p_threshold[mV] = 880' ))
fig.add_trace(go.Scatter(x=df_1050g['g_threshold[mV]'], y=df_1050g['g_count']/7200, mode='markers', name='g_threshold[mV] = 1050'))
fig.add_hline( 1)

# %%
df_880p = df_varia[(df_varia['p_tensione[V]'] == 880) & (df_varia["p_threshold[mV]"]>140) & (df_varia["p_threshold[mV]"]<180)]




p_x = df_880p['p_threshold[mV]'].to_numpy()
p_y = df_880p['p_count'].to_numpy()
p_yerr = np.sqrt(df_880p['p_count'].to_numpy())

# sort p arrays by p_x while keeping pairings
idx = np.argsort(p_x)
p_x = p_x[idx]
p_y = p_y[idx]
p_yerr = p_yerr[idx]

p_LS = LeastSquares( p_x , p_y , p_yerr , line)

m = Minuit( p_LS , a = 0 , b = 1e3)

#m.fixed["a"] = True

m.migrad()
m.hesse()

print( m.fval)
display(m)
# Out:
# nan
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = nan                        │              Nfcn = 764              │
# │ EDM = nan (Goal: 0.0002)         │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │         INVALID Minimum          │   ABOVE EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │     Covariance FORCED pos. def.      │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ a    │     0     │    nan    │            │            │         │         │       │
# │ 1 │ b    │    1e3    │    nan    │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬─────────┐
# │   │   a   b │
# ├───┼─────────┤
# │ a │ nan nan │
# │ b │ nan nan │
# └───┴─────────┘

# %%
df_1050g = df_varia[(df_varia['g_tensione[V]'] == 1050) & (df_varia["g_threshold[mV]"]>110) & (df_varia["g_threshold[mV]"]<130)]

g_x = df_1050g['g_threshold[mV]'].to_numpy()
g_y = df_1050g['g_count'].to_numpy()
g_yerr = np.sqrt(df_1050g['g_count'].to_numpy())

# sort g arrays by g_x while keeping pairings
idx = np.argsort(g_x)
g_x = g_x[idx]
g_y = g_y[idx]
g_yerr = g_yerr[idx]

g_LS = LeastSquares( g_x , g_y , g_yerr , line)

m = Minuit( g_LS , a = 0 , b = 1e3)

#m.fixed["a"] = True

m.migrad()
m.hesse()

display(m)
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 4.147e-21                  │              Nfcn = 55               │
# │ EDM = 4.13e-21 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ a    │    -6     │    12     │            │            │         │         │       │
# │ 1 │ b    │   6.2e3   │   1.4e3   │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬───────────────────┐
# │   │        a        b │
# ├───┼───────────────────┤
# │ a │      137 -16.29e3 │
# │ b │ -16.29e3 1.93e+06 │
# └───┴───────────────────┘

# %% [markdown]
# # Loop

# %% [markdown]
# ## Partenope

# %%
n_punti = 3

df_880p = df_varia[(df_varia['p_tensione[V]'] == 880)]


p_x = df_880p['p_threshold[mV]'].to_numpy()
p_y = df_880p['p_count'].to_numpy()
p_yerr = np.sqrt(df_880p['p_count'].to_numpy())

print( len(p_x))

idx = np.argsort(p_x)
p_x = p_x[idx]
p_y = p_y[idx]
p_yerr = p_yerr[idx]


for i in range(len(p_x)-n_punti+1):
    x = p_x[i:i+n_punti]
    y = p_y[i:i+n_punti]
    err = p_yerr[i:i+n_punti]

    loop_LS = LeastSquares( x , y , err , line)

    m = Minuit( loop_LS , a = -0.1 , b = 1e3)
    m.limits["a"] = (None , 0)
    #m.fixed["a"] = True
    m.migrad()
    m.hesse()
    chi_square_prob = 1 - chi2.cdf(m.fval, df=m.ndof)
    print( i , m.values["a"] , m.fval/m.ndof , chi_square_prob)
# Out:
# 23
# 0 -982.9196801708614 1889.0432060197154 0.0
# 1 -282.05539691489093 40.362203016838606 2.1098356395299334e-10
# 2 -133.61914142540334 26.87540854372685 2.1700253860501562e-07
# 3 -66.34840114848613 1.6364505664608349 0.20081316098522506
# 4 -40.19527470212968 4.293400042545715 0.038260579613297985
# 5 -23.010034332082544 1.4612112704626088 0.2267374932679449
# 6 -16.745416272746056 0.3890417743704246 0.532803516249693
# 7 -12.933892590662566 1.1619288936189447 0.28106586381703114
# 8 -0.035574694666733464 10.80235102221296 0.0010137127395168921
# 9 -0.10000000000000009 nan nan
# 10 -0.10000000000000009 nan nan
# 11 -0.10000000000000009 nan nan
# 12 -0.10000000000000009 nan nan
# 13 -0.10000000000000009 nan nan
# 14 -0.10000000000000009 nan nan
# 15 -0.10000000000000009 nan nan
# 16 -104.25271087071991 73.87668074759974 0.0
# 17 -92.61021570069185 575.2918415660569 0.0
# 18 -92.86095144764991 574.849714710783 0.0
# 19 -78.57117137350384 526.3298676297031 0.0
# 20 -0.00018258404281734641 62.687752303649916 2.4424906541753444e-15

# %%
i = 8

x = p_x[i:i+n_punti]
y = p_y[i:i+n_punti]
err = p_yerr[i:i+n_punti]

loop_LS = LeastSquares( x , y , err , line)

m = Minuit( loop_LS , a = -0.1 , b = 1e3)

m.limits["a"] = (None , 0)
#m.fixed["a"] = True
m.migrad()
m.hesse()

display(m)
print( i , m.values["a"] , m.fval/m.ndof)
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 2.276 (χ²/ndof = 2.3)      │              Nfcn = 57               │
# │ EDM = 3.09e-17 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ a    │    -18    │     6     │            │            │         │         │       │
# │ 1 │ b    │   8.4e3   │   1.0e3   │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬───────────────────┐
# │   │        a        b │
# ├───┼───────────────────┤
# │ a │     37.2  -6.20e3 │
# │ b │  -6.20e3 1.03e+06 │
# └───┴───────────────────┘
# 8 -17.866546266021455 2.276374753247251

# %% [markdown]
# ## Giunone

# %%
n_punti = 3

df_1050g = df_varia[(df_varia['g_tensione[V]'] == 1050)]

g_x = df_1050g['g_threshold[mV]'].to_numpy()
g_y = df_1050g['g_count'].to_numpy()
g_yerr = np.sqrt(df_1050g['g_count'].to_numpy())

# sort g arrays by g_x while keeping pairings
idx = np.argsort(g_x)
g_x = g_x[idx]
g_y = g_y[idx]
g_yerr = g_yerr[idx]


for i in range(len(g_x)-n_punti+1):
    x = g_x[i:i+n_punti]
    y = g_y[i:i+n_punti]
    err = g_yerr[i:i+n_punti]

    loop_LS = LeastSquares( x , y , err , line)

    m = Minuit( loop_LS , a = 0 , b = 1e3)
    m.limits["a"] = (None , 0)
    #m.fixed["a"] = True
    m.migrad()
    m.hesse()
    chi_square_prob = 1 - chi2.cdf(m.fval, df=m.ndof)
    print( i , m.values["a"] , m.fval/m.ndof , chi_square_prob)
# Out:
# 0 0.0 2857.1060742468476 0.0
# 1 0.0 375.5691364511896 0.0
# 2 0.0 47.369186570173824 0.0
# 3 0.0 24.683085711406463 1.9066526135702588e-11
# 4 0.0 10.788823309129738 2.0628781251752493e-05
# 5 0.0 10.848959765317375 1.9424803738399277e-05
# 6 0.0 23.329634882632185 7.380207556195728e-11
# 7 0.0 20.345816678427784 1.4585592733595831e-09
# 8 0.0 nan nan
# 9 0.0 nan nan
# 10 0.0 nan nan
# 11 0.0 nan nan
# 12 0.0 nan nan
# 13 0.0 nan nan
# 14 0.0 nan nan
# 15 0.0 95.31387836740166 0.0
# 16 0.0 83.91629698475398 0.0
# 17 0.0 196.2641862761903 0.0
# 18 0.0 113.96028451546513 0.0

# %%
i = 5

x = g_x[i:i+n_punti]
y = g_y[i:i+n_punti]
err = g_yerr[i:i+n_punti]

loop_LS = LeastSquares( x , y , err , line)

m = Minuit( loop_LS , a = 0 , b = 1e3)

m.limits["a"] = (None , 0)
#m.fixed["a"] = True
m.migrad()
m.hesse()

display(m)
print( i , m.values["a"] , m.fval/m.ndof)
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 21.7 (χ²/ndof = 10.8)      │              Nfcn = 20               │
# │ EDM = 6.06e-16 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ a    │    0.0    │    0.1    │            │            │         │         │  yes  │
# │ 1 │ b    │  5.42e3   │  0.04e3   │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬───────────────────┐
# │   │        a        b │
# ├───┼───────────────────┤
# │ a │        0        0 │
# │ b │        0 1.81e+03 │
# └───┴───────────────────┘
# 5 0.0 10.848959765317375
