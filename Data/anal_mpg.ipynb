# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from pathlib import Path
import numpy as np

# %% [markdown]
# # vecchia analisi

# %%
#prendo path per tutti uguale
DATA_FILE = Path('Data') / 'V_settings2.csv'
if not DATA_FILE.exists():
    for p in Path.cwd().parents:
        candidate = p / 'Data' / 'V_settings2.csv'
        if candidate.exists():
            DATA_FILE = candidate
            break
df_variap = pd.read_csv(DATA_FILE, sep = r',', header = 0, engine='python') #skiprow=21

display(df_variap)
# Out:
#     p_tensione[V]  g_tensione[V]  p_count  g_count  pg_doppie  tempo[min]  \
# 0             728            875     4126     8163       3276           3
# 1             728            875     3304     8129       2573           3
# 2             728            875     2561     8133       2008           3
# 3             728            875     1897     7955       1467           3
# 4             728            875     1473     8095       1128           3
# 5             728            875     1268     8187        965           3
# 6             728            875     1230     5564        918           3
# 7             728            875     1508     5544       1146           3
# 8             728            875     1942     5599       1451           3
# 9             728            875     2652     5672       2035           3
# 10            728            875     3242     5596       2476           3
# 11            728            875     3956     5400       3003           3
# 12            728            875     4840     5645       3751           3
# 13            728            875     4779     4817       3462           3
# 14            728            875     3998     4822       2952           3
# 15            728            875     3282     4831       2415           3
# 16            728            875     2460     4791       1789           3
# 17            728            875     1944     4826       1388           3
# 18            728            875     1514     4968       1087           3
# 19            728            875     1222     4901        886           3
# 20            728            875      972     4850        688           3
# 21            728            875      734     4776        517           3
# 22            728            875      628     4916        438           3
# 23            728            875      521     4858        342           3
# 24            728            875      421     4870        271           3
# 25            728            875      535     4874        229           3
# 26            728            875      538     4971        192           3
# 27            728            875      247     4919        172           3
# 28            728            875      230     4719        145           3
# 29            728            875      170     4691        110           3
# 30            728            875      191     2038        101           3
# 31            728            875      189     1988        104           3
# 32            728            875      314     1811        173           3
# 33            728            875      342     1797        181           3
# 34            728            875      400     2019        212           3
# 35            728            875      164     2089         84           3
# 36            728            875      127     2010         59           3
# 37            728            875      108     2041         57           3
# 38            728            875       89     2034         51           3
#
#     p_threshold[mV]  g_threshold[mV]
# 0                62               22
# 1                69               22
# 2                76               22
# 3                83               22
# 4                90               22
# 5                97               22
# 6                97               35
# 7                90               35
# 8                83               35
# 9                76               35
# 10               69               35
# 11               62               35
# 12               55               35
# 13               55               45
# 14               62               45
# 15               69               45
# 16               76               45
# 17               83               45
# 18               90               45
# 19               97               45
# 20              104               45
# 21              111               45
# 22              118               45
# 23              125               45
# 24              132               45
# 25              139               45
# 26              146               45
# 27              153               45
# 28              160               45
# 29              167               45
# 30              167               70
# 31              160               70
# 32              146               70
# 33              139               70
# 34              132               70
# 35              174               70
# 36              184               70
# 37              194               70
# 38              202               70

# %%
DATA_FILE = Path('Data') / 'V_settings3.csv'
if not DATA_FILE.exists():
    for p in Path.cwd().parents:
        candidate = p / 'Data' / 'V_settings3.csv'
        if candidate.exists():
            DATA_FILE = candidate
            break
df_variag = pd.read_csv(DATA_FILE, sep = r',', header=0, engine='python')
display(df_variag)
# Out:
#     p_tensione[V]  g_tensione[V]  p_threshold[mV]  g_threshold[mV]  p_count  \
# 0             728            875               83               22     1897
# 1             728            875               83               35     1942
# 2             728            875               83               45     1944
# 3             728            875               83               55     1967
# 4             728            875               83               62     1981
# 5             728            875               83               69     1921
# 6             728            875               83               76     1903
# 7             728            875               83               83     1952
# 8             728            875               83              118     1834
# 9             728            875               83              125     1849
# 10            728            875               83              132     1967
# 11            728            875               83              139     1990
# 12            728            875               83              146     1889
#
#     g_count  pg_doppie  tempo[min]
# 0      7955       1467           3
# 1      5599       1451           3
# 2      4826       1388           3
# 3      3765       1282           3
# 4      2940       1169           3
# 5      2154        995           3
# 6      1693        853           3
# 7      1293        712           3
# 8       454        289           3
# 9       353        223           3
# 10      323        209           3
# 11      292        180           3
# 12      207        122           3

# %%
df_22 = df_variap[df_variap['g_threshold[mV]'] == 22]
df_35 = df_variap[df_variap['g_threshold[mV]'] == 35]
df_45 = df_variap[df_variap['g_threshold[mV]'] == 45]
df_70 = df_variap[df_variap['g_threshold[mV]'] == 70]
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_22['p_threshold[mV]'], y=df_22['p_count'], mode='markers', name='g_threshold[mV] = 22'))
fig.add_trace(go.Scatter(x=df_35['p_threshold[mV]'], y=df_35['p_count'], mode='markers', name='g_threshold[mV] = 35'))
fig.add_trace(go.Scatter(x=df_22['p_threshold[mV]'], y=df_22['pg_doppie'], mode = 'markers', name='coinc g_threshold[mV] = 22'))
fig.add_trace(go.Scatter(x=df_35['p_threshold[mV]'], y=df_35['pg_doppie'], mode = 'markers', name='coinc g_threshold[mV] = 35'))
fig.add_trace(go.Scatter(x=df_45['p_threshold[mV]'], y=df_45['p_count'], mode='markers', name='g_threshold[mV] = 45'))
fig.add_trace(go.Scatter(x=df_45['p_threshold[mV]'], y=df_45['pg_doppie'], mode = 'markers', name='coinc g_threshold[mV] = 45'))
fig.add_trace(go.Scatter(x=df_70['p_threshold[mV]'], y=df_70['p_count'], mode='markers', name='g_threshold[mV] = 70', marker =dict(color = '#1A73E8')))
fig.update_layout(title= 'tensione vs thr', xaxis_title='p_threshold[mV]', yaxis_title='p_count')
fig.show()

# %%
df_45p = df_variag[df_variag['p_threshold[mV]'] == 83]
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_45p['g_threshold[mV]'], y=df_45p['g_count'], mode='markers', name='g_threshold[mV] = 45'))
fig.add_trace(go.Scatter(x=df_45['p_threshold[mV]'], y=df_45['p_count'], mode='markers', name='g_threshold[mV] = 45'))

# %%
fig = go.Figure()
# fig.add_trace(go.Scatter(x=df_22['p_threshold[mV]'], y=df_22['pg_doppie']/df_22['p_count'], mode='markers', name='coinc 22'))
# fig.add_trace(go.Scatter(x=df_35['p_threshold[mV]'], y=df_35['pg_doppie']/df_35['p_count'], mode='markers', name='coin 35'))
fig.add_trace(go.Scatter(x=df_45['p_threshold[mV]'], y=df_45['pg_doppie']/df_45['p_count'], mode='markers', name='coinc 45'))
# fig.add_trace(go.Scatter(x=df_70['p_threshold[mV]'], y=df_70['pg_doppie']/df_70['p_count'], mode='markers', name='coinc 70', marker =dict(color = '#1A73E8')))
fig.add_trace(go.Scatter(x = df_45p['g_threshold[mV]'], y = df_45p['pg_doppie']/df_45p['g_count'], mode='markers', name='coinc 45p'))

# %% [markdown]
# # nuova analisi

# %%
#prendo path per tutti uguale
DATA_FILE = Path('Data') / 'ch_4-5.csv'
if not DATA_FILE.exists():
    for p in Path.cwd().parents:
        candidate = p / 'Data' / 'ch_4-5.csv'
        if candidate.exists():
            DATA_FILE = candidate
            break
df_varia = pd.read_csv(DATA_FILE, sep = r',', skiprows = 0, engine='python')
display(df_varia)
# Out:
#     p_tensione[V]  g_tensione[V]  p_threshold[mV]  g_threshold[mV]  p_count  \
# 0             780            950              141              120   1420.0
# 1             780            950              253              153    128.0
# 2             780            950              200              183    418.0
# 3             780            950              151              209   1117.0
# 4             780            950              234              192    218.0
# 5             780            950              212              201    378.0
# 6             780            950              238              224    192.0
# 7             780            950              187              171    563.0
# 8             800            950              237              167    373.0
# 9             800            980              187              173   1088.0
# 10            800            980              212              190    635.0
# 11            800            980              230              205    415.0
# 12            800            980              249              248    304.0
# 13            800            980              253              254    264.0
# 14            800            950              175              206   1298.0
# 15            780            950              230              180    231.0
# 16            780            950              173              254    727.0
# 17            780            950              222              242    240.0
# 18            780            950              211              176    302.0
# 19            780            950              125              217   2058.0
# 20            780            950              116              217   2532.0
# 21            780            950              106              217   3314.0
# 22            780            950               96              217   4252.0
# 23            780            950               85              217   4889.0
# 24            780            950               76              217   5300.0
# 25            780            950               66              217   5642.0
# 26            780            950               54              217   6422.0
# 27            780            950               48              217   6932.0
# 28            780            950               60              217   6004.0
# 29            980            950              150              215  16592.0
# 30            880            950              224              215   4087.0
# 31            880            950              205              215   4720.0
# 32            880           1050              194              215   5059.0
# 33            880           1050              175              187   5263.0
# 34            880           1050              166              174   5557.0
# 35            880           1050              158              163   5559.0
# 36            880           1050              148              148   5784.0
# 37            880           1050              138              136   5893.0
# 38            880           1050              121              123   6389.0
# 39            880           1050              108              114   7130.0
# 40            880           1050               98              104   7936.0
# 41            880           1050               89               94   9751.0
# 42            880           1050               79               81  13408.0
# 43            880           1050              239               68   1411.0
# 44            880           1050              253               49   1635.0
# 45            880           1050              253              205   1213.0
# 46            880           1050              223              247   2270.0
# 47            880           1050               42              254  57268.0
# 48            880           1050              178              166      NaN
#
#     g_count  pg_doppie  gm_doppie  pgm_triple  m_tensione[V]  m_threshold[mV]
# 0    1548.0      683.0        NaN         NaN            NaN              NaN
# 1     815.0       51.0        NaN         NaN            NaN              NaN
# 2     466.0      131.0        NaN         NaN            NaN              NaN
# 3     269.0      133.0        NaN         NaN            NaN              NaN
# 4     372.0       65.0        NaN         NaN            NaN              NaN
# 5     334.0      106.0        NaN         NaN            NaN              NaN
# 6     197.0       37.0        NaN         NaN            NaN              NaN
# 7     518.0      176.0        NaN         NaN            NaN              NaN
# 8     557.0      126.0        NaN         NaN            NaN              NaN
# 9    1115.0      466.0        NaN         NaN            NaN              NaN
# 10    820.0      236.0        NaN         NaN            NaN              NaN
# 11    586.0      144.0        NaN         NaN            NaN              NaN
# 12    300.0       80.0        NaN         NaN            NaN              NaN
# 13    293.0       81.0        NaN         NaN            NaN              NaN
# 14    270.0      160.0        NaN         NaN            NaN              NaN
# 15    480.0       79.0        NaN         NaN            NaN              NaN
# 16    108.0       52.0        NaN         NaN            NaN              NaN
# 17    151.0       30.0        NaN         NaN            NaN              NaN
# 18    526.0      122.0       75.0        64.0            NaN              NaN
# 19      NaN      136.0       72.0        63.0            NaN              NaN
# 20      NaN      129.0       86.0        74.0            NaN              NaN
# 21      NaN      130.0       68.0        62.0            NaN              NaN
# 22      NaN      143.0       68.0        66.0            NaN              NaN
# 23      NaN      160.0       82.0        80.0            NaN              NaN
# 24      NaN      174.0       88.0        85.0            NaN              NaN
# 25      NaN      137.0       74.0        73.0            NaN              NaN
# 26      NaN      163.0       92.0        93.0            NaN              NaN
# 27      NaN      182.0       83.0        82.0            NaN              NaN
# 28      NaN      410.0      199.0       195.0            NaN              NaN
# 29      NaN      188.0       82.0        81.0            NaN              NaN
# 30      NaN      155.0       73.0        73.0            NaN              NaN
# 31      NaN      162.0       80.0        75.0            NaN              NaN
# 32   2496.0        NaN     1023.0      1012.0         1150.0            254.0
# 33   3488.0        NaN     1388.0      1376.0         1150.0            254.0
# 34   4207.0        NaN     1658.0      1649.0         1150.0            254.0
# 35   4528.0        NaN     1667.0      1652.0         1150.0            254.0
# 36   4847.0        NaN     2671.0      2662.0         1150.0            189.0
# 37   5155.0        NaN     2676.0      2660.0         1150.0            191.0
# 38   5543.0        NaN     3420.0      3395.0         1150.0             76.0
# 39   5593.0        NaN     3450.0      3428.0         1150.0             50.0
# 40   6001.0        NaN     3558.0      3562.0         1150.0             40.0
# 41   6359.0        NaN     3636.0      3598.0         1150.0             40.0
# 42   7102.0        NaN     3590.0      2493.0         1150.0             35.0
# 43   9762.0        NaN     3752.0       623.0         1150.0             26.0
# 44  19373.0        NaN     3835.0      1086.0         1150.0             26.0
# 45   3033.0        NaN     1972.0      1357.0         1150.0             26.0
# 46   1714.0        NaN     1047.0      1003.0         1150.0             26.0
# 47   1570.0        NaN      968.0       957.0         1150.0             26.0
# 48      NaN     4303.0     3024.0      2978.0         1200.0             40.0

# %%
df_780p = df_varia[df_varia['p_tensione[V]'] == 780]
df_950g = df_varia[df_varia['g_tensione[V]'] == 950]
df_800p = df_varia[df_varia['p_tensione[V]'] == 800]
df_980g = df_varia[df_varia['g_tensione[V]'] == 980]
df_880p = df_varia[df_varia['p_tensione[V]'] == 880]
df_1050g = df_varia[df_varia['g_tensione[V]'] == 1050]
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_780p['p_threshold[mV]'], y=df_780p['p_count'], mode='markers', name='p_threshold[mV] = 780', error_y=dict(type='data', array=np.sqrt(df_780p['p_count']), visible=True)))
fig.add_trace(go.Scatter(x=df_950g['g_threshold[mV]'], y=df_950g['g_count'], mode='markers', name='g_threshold[mV] = 950', error_y=dict(type='data', array=np.sqrt(df_950g['g_count']), visible=True)))
fig.add_trace(go.Scatter(x=df_880p['p_threshold[mV]'], y=df_880p['p_count'], mode='markers', name='p_threshold[mV] = 880', error_y=dict(type='data', array=np.sqrt(df_880p['p_count']), visible=True)))
fig.add_trace(go.Scatter(x=df_1050g['g_threshold[mV]'], y=df_1050g['g_count'], mode='markers', name='g_threshold[mV] = 1050', error_y=dict(type='data', array=np.sqrt(df_1050g['g_count']), visible=True)))
# fig.add_trace(go.Scatter(x=df_800p['p_threshold[mV]'], y=df_800p['p_count'], mode='markers', name='p_threshold[mV] = 800', error_y=dict(type='data', array=np.sqrt(df_800p['p_count']), visible=True)))
# fig.add_trace(go.Scatter(x=df_980g['g_threshold[mV]'], y=df_980g['g_count'], mode='markers', name='g_threshold[mV] = 980', error_y=dict(type='data', array=np.sqrt(df_980g['g_count']), visible=True)))

# %% [markdown]
# # Triple vs Doppie

# %%
DATA_FILE = Path('Data') / 't_vs_d.csv'

if not DATA_FILE.exists():
    for p in Path.cwd().parents:
        candidate = p / 'Data' / 't_vs_d.csv'
        if candidate.exists():
            DATA_FILE = candidate
            break

df_tvd = pd.read_csv(DATA_FILE, sep = r',', skiprows = 0, engine='python')
display(df_tvd)
# Out:
#     p_tensione[V]  g_tensione[V]  m_tensione[V]  p_threshold[mV]  \
# 0             780            950           1150              215
# 1             780            950           1150              207
# 2             780            950           1150              200
# 3             780            950           1150              182
# 4             780            950           1150              168
# 5             780            950           1150              137
# 6             780            950           1150              137
# 7             780            950           1150              137
# 8             780            950           1150              125
# 9             780            950           1150              125
# 10            780            950           1150              116
# 11            780            950           1150              106
# 12            780            950           1150               95
# 13            780            950           1150               86
# 14            780            950           1150               76
# 15            780            950           1150               66
# 16            780            950           1150               54
# 17            780            950           1150               48
# 18            780            950           1150               60
# 19            980            950           1150              150
# 20            880            950           1150              224
# 21            880            950           1150              205
#
#     g_threshold[mV]  m_threshold[mV]  pg_doppie  m_count  gm_doppie  \
# 0               218              154         74   9852.0        101
# 1               218              154         53   9995.0         86
# 2               218              179         85   7664.0        106
# 3               218              179        101   7629.0        101
# 4               218              179        104   7436.0         96
# 5               218              179        127   7433.0         97
# 6               218              235        127   4596.0         82
# 7               218              254        127   4133.0         68
# 8               218              179        121   3996.0         75
# 9               218              179        136      NaN         72
# 10              218              179        129      NaN         86
# 11              218              179        130      NaN         68
# 12              218              179        143      NaN         68
# 13              218              179        160      NaN         82
# 14              218              179        174      NaN         88
# 15              218              179        137      NaN         74
# 16              218              179        163      NaN         92
# 17              218              179        182      NaN         83
# 18              169              179        410      NaN        199
# 19              215              179        188      NaN         82
# 20              215              179        155      NaN         73
# 21              215              179        162      NaN         80
#
#     pgm_triple
# 0           50
# 1           34
# 2           57
# 3           62
# 4           63
# 5           83
# 6           73
# 7           56
# 8           64
# 9           63
# 10          74
# 11          62
# 12          66
# 13          80
# 14          85
# 15          73
# 16          93
# 17          82
# 18         195
# 19          81
# 20          73
# 21          75

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_tvd['p_threshold[mV]'], y=(df_tvd['gm_doppie']), mode='markers', name='gm_doppie', error_y=dict(type='data', array=np.sqrt(df_tvd['gm_doppie']), visible=True)))

fig.add_trace(go.Scatter(x=df_tvd['p_threshold[mV]'], y=(df_tvd['pgm_triple']), mode='markers', name='pgm_triple', error_y=dict(type='data', array=np.sqrt(df_tvd['pgm_triple']), visible=True)))

fig.update_layout(title= 'doppie gm vs triple', xaxis_title='p_threshold[mV]', yaxis_title='count')
fig.show()



fig1 = go.Figure()
fig1.add_trace(go.Scatter(x=df_tvd['p_threshold[mV]'], y=(df_tvd['pgm_triple']/df_tvd['gm_doppie']), mode='markers', name='ratio'))
fig1.update_layout( title="ratio" , xaxis_title = "p_threshold[mV]" , yaxis_title = "ratio t/d")
