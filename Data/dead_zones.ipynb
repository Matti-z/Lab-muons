# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from pathlib import Path
import numpy as np

# %%
#prendo path per tutti uguale
DATA_FILE = Path('Data') / 'dead_zones.csv'
if not DATA_FILE.exists():
    for p in Path.cwd().parents:
        candidate = p / 'Data' / 'dead_zones.csv'
        if candidate.exists():
            DATA_FILE = candidate
            break
df = pd.read_csv(DATA_FILE, sep = r',', header = 0, engine='python') #skiprow=21

display(df)
