# %%
import pandas as pd
import plotly
import plotly.express as px
import plotly.graph_objects as go
from pathlib import Path

# %%
#prendo path per tutti uguale
DATA_FILE = Path('Data') / 'V_settings2.txt'
if not DATA_FILE.exists():
    for p in Path.cwd().parents:
        candidate = p / 'Data' / 'V_settings2.txt'
        if candidate.exists():
            DATA_FILE = candidate
            break

# %%
df = pd.read_csv(DATA_FILE, sep = r'\s+', skiprows = 21, header = None, engine='python')
df.columns = ['p_t', 'p_c', 'g_t', 'g_c', 'coincidenze', 'tempo_misura_min', 'thr_p', 'thr_g']
print (df)
# Out:
#     p_t   p_c  g_t   g_c  coincidenze  tempo_misura_min  thr_p  thr_g
# 0   728  4126  875  8163         3276                 3     62     22
# 1   728  3304  875  8129         2573                 3     69     22
# 2   728  2561  875  8133         2008                 3     76     22
# 3   728  1897  875  7955         1467                 3     83     22
# 4   728  1473  875  8095         1128                 3     90     22
# 5   728  1268  875  8187          965                 3     97     22
# 6   728  1230  875  5564          918                 3     97     35
# 7   728  1508  875  5544         1146                 3     90     35
# 8   728  1942  875  5599         1451                 3     83     35
# 9   728  2652  875  5672         2035                 3     76     35
# 10  728  3242  875  5596         2476                 3     69     35
# 11  728  3956  875  5400         3003                 3     62     35
# 12  728  4840  875  5645         3751                 3     55     35
# 13  728  4779  875  4817         3462                 3     55     45
# 14  728  3998  875  4822         2952                 3     62     45
# 15  728  3282  875  4831         2415                 3     69     45
# 16  728  2460  875  4791         1789                 3     76     45
# 17  728  1944  875  4826         1388                 3     83     45
# 18  728  1514  875  4968         1087                 3     90     45
# 19  728  1222  875  4901          886                 3     97     45
# 20  728   972  875  4850          688                 3    104     45
# 21  728   734  875  4776          517                 3    111     45
# 22  728   628  875  4916          438                 3    118     45
# 23  728   521  875  4858          342                 3    125     45
# 24  728   421  875  4870          271                 3    132     45
# 25  728   535  875  4874          229                 3    139     45
# 26  728   538  875  4971          192                 3    146     45
# 27  728   247  875  4919          172                 3    153     45
# 28  728   230  875  4719          145                 3    160     45
# 29  728   170  875  4691          110                 3    167     45
# 30  728   191  875  2038          101                 3    167     70
# 31  728   189  875  1988          104                 3    160     70
# 32  728   314  875  1811          173                 3    146     70

# %%
df_22 = df[df['thr_g'] == 22]
df_35 = df[df['thr_g'] == 35]
df_45 = df[df['thr_g'] == 45]
df_70 = df[df['thr_g'] == 70]
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_22['thr_p'], y=df_22['p_c'], mode='markers', name='thr_g = 22'))
fig.add_trace(go.Scatter(x=df_35['thr_p'], y=df_35['p_c'], mode='markers', name='thr_g = 35'))
fig.add_trace(go.Scatter(x=df_22['thr_p'], y=df_22['coincidenze'], mode = 'markers', name='coinc thr_g = 22'))
fig.add_trace(go.Scatter(x=df_35['thr_p'], y=df_35['coincidenze'], mode = 'markers', name='coinc thr_g = 35'))
fig.add_trace(go.Scatter(x=df_45['thr_p'], y=df_45['p_c'], mode='markers', name='thr_g = 45'))
fig.add_trace(go.Scatter(x=df_45['thr_p'], y=df_45['coincidenze'], mode = 'markers', name='coinc thr_g = 45'))
fig.add_trace(go.Scatter(x=df_70['thr_p'], y=df_70['p_c'], mode='markers', name='thr_g = 70', marker =dict(color = '#1A73E8')))
fig.update_layout(title= 'tensione vs thr', xaxis_title='thr_p', yaxis_title='p_c')
fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_22['thr_p'], y=df_22['coincidenze']/df_22['p_c'], mode='markers', name='coinc 22'))
fig.add_trace(go.Scatter(x=df_35['thr_p'], y=df_35['coincidenze']/df_35['p_c'], mode='markers', name='coin 35'))
fig.add_trace(go.Scatter(x=df_45['thr_p'], y=df_45['coincidenze']/df_45['p_c'], mode='markers', name='coinc 45'))
fig.add_trace(go.Scatter(x=df_70['thr_p'], y=df_70['coincidenze']/df_70['p_c'], mode='markers', name='coinc 70', marker =dict(color = '#1A73E8')))
