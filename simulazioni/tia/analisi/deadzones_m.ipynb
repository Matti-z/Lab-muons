# %% [markdown]
# analisi risultati sim per minerva

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append('/home/matti/uni/lab/Lab-muons/Data/calibration')
from error_prop import propagazione_errore


frac = lambda val: propagazione_errore(["a", "b"] , "a/b" , val , [[np.sqrt(val[0]) , 0] , [0 , np.sqrt(val[1])]] , Display=False)

# %%
def count_hits(df):
    """
    Count events where Minerva and Partenope both == 1,
    and count events where all three detectors == 1.
    
    Parameters:
    df : pandas.DataFrame
        DataFrame with columns: HitBottom, HitTop, HitMiddle

    """
    count_both = ((df['HitBottom'] == 1) & (df['HitTop'] == 1)).sum()
    count_all_three = ((df['HitBottom'] == 1) & (df['HitTop'] == 1) & (df['HitMiddle'] == 1)).sum()
    return count_both,count_all_three

def filtering(a, b, c, d, peso_a = 0.54, peso_c = 0.54):
    filt1 = int(a * peso_a + b *(1-peso_a))
    filt2 = int(c * peso_c + d *(1-peso_c))
    return filt2 / filt1

# %% [markdown]
# # cos

# %%
gmp0_m = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos/run_0.csv', sep = ',', skiprows = 0)
print(gmp0_m.columns.tolist())
# gmp0_m.columns = ["HitID", "coincidence", "top", "mid", "bottom", "decay", "decayTime"]
gmp0_p = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos/run_1.csv', sep = ',',)
# gmp0_p.columns = ["HitID", "coincidence", "top", "mid", "bottom", "decay", "decayTime"]
gmp15_m = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos/run_2.csv', sep = ',',)
# gmp15_m.columns = ["HitID", "coincidence", "top", "mid", "bottom", "decay", "decayTime"]
gmp15_p = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos/run_3.csv', sep = ',',)
# gmp15_p.columns = ["HitID", "coincidence", "top", "mid", "bottom", "decay", "decayTime"]
gmp30_m = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos/run_4.csv', sep = ',',)
# gmp30_m.columns = ["HitID", "coincidence", "top", "mid", "bottom", "decay", "decayTime"]
gmp30_p = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos/run_5.csv', sep = ',',)
# gmp30_p.columns = ["HitID", "coincidence", "top", "mid", "bottom", "decay", "decayTime"]
gmp45_m = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos/run_6.csv', sep = ',',)
# gmp45_m.columns = ["HitID", "coincidence", "top", "mid", "bottom", "decay", "decayTime"]
gmp45_p = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos/run_7.csv', sep = ',',)
# gmp45_p.columns = ["HitID", "coincidence", "top", "mid", "bottom", "decay", "decayTime"]
gmp60_m = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos/run_8.csv', sep = ',',)
# gmp60_m.columns = ["HitID", "coincidence", "top", "mid", "bottom", "decay", "decayTime"]
gmp60_p = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos/run_9.csv', sep = ',',)
# gmp60_p.columns = ["HitID", "coincidence", "top", "mid", "bottom", "decay", "decayTime"]
# Out:
# ['EventID', 'Coincidence', 'HitTop', 'HitMiddle', 'HitBottom', 'Decay', 'DecayTime_ns']

# %%
d0m, t0m = count_hits(gmp0_m)
d0p, t0p = count_hits(gmp0_p)
d15m, t15m = count_hits(gmp15_m)
d15p, t15p = count_hits(gmp15_p)
d30m, t30m = count_hits(gmp30_m)
d30p, t30p = count_hits(gmp30_p)
d45m, t45m = count_hits(gmp45_m)
d45p, t45p = count_hits(gmp45_p)
d60m, t60m = count_hits(gmp60_m)
d60p, t60p = count_hits(gmp60_p)

# %%
print(t0m/d0m, t0p/d0p)
print(t15m/d15m, t15p/d15p)
print(t30m/d30m, t30p/d30p)
print(t45m/d45m, t45p/d45p)
print(t60m/d60m, t60p/d60p)
# Out:
# 0.993960310612597 0.9946813749630651
# 0.8810436503029554 0.8855810616929699
# 0.5938647656081227 0.6016713091922006
# 0.3098172545686358 0.30856149500217295
# 0.17941712204007285 0.18189730200174065

# %% [markdown]
# # cos^2

# %%
gmp0_ms = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_squared/run_0.csv', sep = ',', skiprows = 0)

gmp0_ps = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_squared/run_1.csv', sep = ',',)

gmp15_ms = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_squared/run_2.csv', sep = ',',)

gmp15_ps = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_squared/run_3.csv', sep = ',',)

gmp30_ms = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_squared/run_4.csv', sep = ',',)

gmp30_ps = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_squared/run_5.csv', sep = ',',)

gmp45_ms = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_squared/run_6.csv', sep = ',',)

gmp45_ps = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_squared/run_7.csv', sep = ',',)

gmp60_ms = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_squared/run_8.csv', sep = ',',)

gmp60_ps = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_squared/run_9.csv', sep = ',',)

# %%
d0ms, t0ms = count_hits(gmp0_ms)
d0ps, t0ps = count_hits(gmp0_ps)
d15ms, t15ms = count_hits(gmp15_ms)
d15ps, t15ps = count_hits(gmp15_ps)
d30ms, t30ms = count_hits(gmp30_ms)
d30ps, t30ps = count_hits(gmp30_ps)
d45ms, t45ms = count_hits(gmp45_ms)
d45ps, t45ps = count_hits(gmp45_ps)
d60ms, t60ms = count_hits(gmp60_ms)
d60ps, t60ps = count_hits(gmp60_ps)

# %%
print(t0ms/d0ms, t0ps/d0ps)
print(t15ms/d15ms, t15ps/d15ps)
print(t30ms/d30ms, t30ps/d30ps)
print(t45ms/d45ms, t45ps/d45ps)
print(t60ms/d60ms, t60ps/d60ps)
# print(t60ms,d60ms, t60ps,d60ps)
# Out:
# 0.9961832061068703 0.9954431175361408
# 0.8910631430300585 0.8824267782426778
# 0.6002475247524752 0.591041061800083
# 0.29842931937172773 0.2807570977917981
# 0.17121588089330025 0.16548463356973994

# %% [markdown]
# # cos^1/3

# %%
gmp0_m1 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_1_3/run_0.csv', sep = ',', skiprows = 0)

gmp0_p1 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_1_3/run_1.csv', sep = ',',)

gmp15_m1 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_1_3/run_2.csv', sep = ',',)

gmp15_p1 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_1_3/run_3.csv', sep = ',',)

gmp30_m1 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_1_3/run_4.csv', sep = ',',)

gmp30_p1 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_1_3/run_5.csv', sep = ',',)

gmp45_m1 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_1_3/run_6.csv', sep = ',',)

gmp45_p1 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_1_3/run_7.csv', sep = ',',)

gmp60_m1 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_1_3/run_8.csv', sep = ',',)

gmp60_p1 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_1_3/run_9.csv', sep = ',',)

# %%
d0m1, t0m1 = count_hits(gmp0_m1)
d0p1, t0p1 = count_hits(gmp0_p1)
d15m1, t15m1 = count_hits(gmp15_m1)
d15p1, t15p1 = count_hits(gmp15_p1)
d30m1, t30m1 = count_hits(gmp30_m1)
d30p1, t30p1 = count_hits(gmp30_p1)
d45m1, t45m1 = count_hits(gmp45_m1)
d45p1, t45p1 = count_hits(gmp45_p1)
d60m1, t60m1 = count_hits(gmp60_m1)
d60p1, t60p1 = count_hits(gmp60_p1)
print(d60m1, t60m1)
# Out:
# 1425 227

# %% [markdown]
# # cos^2/3

# %%
gmp0_m2 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_2_3/run_0.csv', sep = ',', skiprows = 0)

gmp0_p2 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_2_3/run_1.csv', sep = ',',)

gmp15_m2 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_2_3/run_2.csv', sep = ',',)

gmp15_p2 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_2_3/run_3.csv', sep = ',',)

gmp30_m2 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_2_3/run_4.csv', sep = ',',)

gmp30_p2 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_2_3/run_5.csv', sep = ',',)

gmp45_m2 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_2_3/run_6.csv', sep = ',',)

gmp45_p2 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_2_3/run_7.csv', sep = ',',)

gmp60_m2 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_2_3/run_8.csv', sep = ',',)

gmp60_p2 = pd.read_csv('/home/matti/uni/lab/Lab-muons/simulazioni/tia/g4/results/gmp/cos_2_3/run_9.csv', sep = ',',)

# %%
d0m2, t0m2 = count_hits(gmp0_m2)
d0p2, t0p2 = count_hits(gmp0_p2)
d15m2, t15m2 = count_hits(gmp15_m2)
d15p2, t15p2 = count_hits(gmp15_p2)
d30m2, t30m2 = count_hits(gmp30_m2)
d30p2, t30p2 = count_hits(gmp30_p2)
d45m2, t45m2 = count_hits(gmp45_m2)
d45p2, t45p2 = count_hits(gmp45_p2)
d60m2, t60m2 = count_hits(gmp60_m2)
d60p2, t60p2 = count_hits(gmp60_p2)
print(d0m2, d60p2)
# Out:
# 9240 1278

# %% [markdown]
# # peso

# %%
angles = [0, 15, 30, 45, 60]
variants = ['', 's', '1', '2']  # The suffixes: d0m, d0ms, d0m1, d0m2
polarities = ['m', 'p']

results = {}

for angle in angles:
    results[angle] = {}
    
    for variant in variants:
        # Get both m and p polarities for this angle/variant
        d_m = globals()[f'd{angle}m{variant}']
        t_m = globals()[f't{angle}m{variant}']
        d_p = globals()[f'd{angle}p{variant}']
        t_p = globals()[f't{angle}p{variant}']
        
        # Apply filtering (or store as-is, depending on your logic)
        results[angle][variant] = filtering(d_m, d_p, t_m, t_p)

print(results)

errors = {}

for angle in angles:
    errors[angle] = {}

    for variant in variants:
        d_m = globals()[f'd{angle}m{variant}']
        d_p = globals()[f'd{angle}p{variant}']
        t_m = globals()[f't{angle}m{variant}']
        t_p = globals()[f't{angle}p{variant}']

        filt1 = int(d_m * 0.54 + d_p * 0.46)
        filt2 = int(t_m * 0.54 + t_p * 0.46)

        errors[angle][variant] = frac([filt2, filt1])

print (errors)
# Out:
# {0: {'': 0.9942735125691546, 's': 0.9958873774122113, '1': 0.9896744412050534, '2': 0.9920807116511173}, 15: {'': 0.8831263696128561, 's': 0.8871794871794871, '1': 0.880920761398849, '2': 0.8838262723154809}, 30: {'': 0.597503228583728, 's': 0.5959470636889992, '1': 0.5967626755534396, '2': 0.5988725065047702}, 45: {'': 0.30914555603263205, 's': 0.28961175236096537, '1': 0.3217601937828018, '2': 0.30294239535847495}, 60: {'': 0.1801962533452275, 's': 0.16747572815533981, '1': 0.15991316931982633, '2': 0.17214397496087636}}
# ...

# %%
from pathlib import Path
default_dir = str(Path(".").absolute()).split("/Lab-muons")[0]+"/Lab-muons/"
universal_dir = lambda path: default_dir + path

DATA_PATH = universal_dir("Data/calibration/dead_zones.csv")

data = pd.read_csv(DATA_PATH, sep=",", header=0)
# print (data)
df_M = data[data['ordine[TtB]'] == 'gmp']

# %%
df_M
# Out:
#    ordine[TtB]  p_distanza[cm]  g_distanza[cm]  m_distanza[cm]   p_count  \
# 12         gmp               0               0               0      9179
# 13         gmp               0               0              15      8800
# 14         gmp               0               0              30      9197
# 15         gmp               0               0              45      8212
# 16         gmp               0               0              60      8285
# 17         gmp               0               0              75      8108
#
#      pm_doppie   gm_doppie   pg_doppie   pgm_triple  tempo[min]
# 12           0        6029      4189.0         4104         NaN
# 13           0        5752      4294.0         3871         NaN
# 14           0        4074      4093.0         2668         NaN
# 15           0        2707      3839.0         1546         NaN
# 16           0        1527      3773.0          710         NaN
# 17           0         550      3961.0          118         NaN

# %%
df_M.columns
# Out:
# Index(['ordine[TtB]', 'p_distanza[cm]', 'g_distanza[cm]', 'm_distanza[cm]',
#        ' p_count', ' pm_doppie', ' gm_doppie', ' pg_doppie', ' pgm_triple',
#        'tempo[min]'],
#       dtype='object')

# %%
frac = lambda a, b: propagazione_errore(
    ["a", "b"],
    "a/b",
    [a, b],
    [[np.sqrt(a), 0], [0, np.sqrt(b)]],
    Display=False
)

# %%
labels = {
    '': r'$\cos(\theta)$',
    's': r'$\cos^{2}(\theta)$',
    '1': r'$\cos^{1/3}(\theta)$',
    '2': r'$\cos^{2/3}(\theta)$'
}

y_M =  ((df_M[' pgm_triple'] - 0.1 * df_M[' pg_doppie'] ) /(df_M[' pg_doppie'])).iloc[:5].values
err_M = np.array([
    frac(a, b)
    for a, b in zip(df_M[' pgm_triple'][:5],
                    df_M[' pg_doppie'][:5])
])

x = np.linspace(0, 60, 5)

plt.figure(figsize= (15,6))
for key in ['', 's', '1', '2']:
    y = [results[t][key] for t in x]
    err_y = [errors[t][key] for t in x]
    plt.errorbar(x, y, err_y, label=labels[key], fmt = '.')

plt.errorbar(x, y_M, yerr= err_M , label = 'Minerva', )
plt.ylabel(r'$ \epsilon $', fontsize = 20)
plt.xlabel('Misalignment [cm]', fontsize = 15)
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.6,)

# plt.savefig('m_eff.pdf')

# %%
# 1. Labels mapping matching your PDF legend
labels = {
    '': r'$\cos(\theta)$',
    's': r'$\cos^{2}(\theta)$',
    '1': r'$\cos^{1/3}(\theta)$',
    '2': r'$\cos^{2/3}(\theta)$'
}

# 2. Alignment distances (x-axis)
x = np.array([0, 15, 30, 45, 60])

# --- CALCULATING AND PLOTTING DISTANCES / SIGMA ---
plt.figure(figsize=(15, 6))

# Loop through each of the 4 theoretical models
for key in ['', 's', '1', '2']:
    # Extract model values and errors for the current key across all x points
    y_model = np.array([results[t][key] for t in x])
    sigma_model = np.array([errors[t][key] for t in x])
    
    # Convert y_M to a numpy array for vector operations
    y_experimental = np.array(y_M)
    
    # Calculate (Experimental - Model) / Sigma
    # Note: If you want absolute distance, change to: np.abs(y_experimental - y_model) / sigma_model
    normalized_distance = (y_experimental / y_model) 
    
    # Plot the normalized distances as points connected by a dashed line
    plt.errorbar(x, normalized_distance,  sigma_model, marker='o', linestyle='--', label=f"Distance to {labels[key]}")

# --- STYLING THE PLOT ---
plt.ylabel(r'$\epsilon_{meas} - \epsilon_{theory}$', fontsize=18)
plt.xlabel('Misalignment [cm]', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add a horizontal line at 0 to clearly show where the experimental data perfectly matches a model
plt.axhline(0, color='black', linestyle=':', alpha=0.5)

plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.6)
plt.xlim(-3, 63)
plt.legend(loc='upper right', fontsize=12)

# plt.show()
# plt.savefig('m_eff_dist.pdf')
